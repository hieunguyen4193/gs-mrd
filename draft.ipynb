# %%
import pandas as pd
import numpy as np
import pathlib
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import RocCurveDisplay
from sklearn.decomposition import NMF
import warnings
warnings.filterwarnings("ignore")
from sklearn.mixture import GaussianMixture
import os
import ot
import pickle
import argparse


data_version = "20240924"
path_to_main_input = os.path.join("./all_samples", data_version)

emdf = pd.read_csv(os.path.join(path_to_main_input, "EM.csv"))
flendf = pd.read_csv(os.path.join(path_to_main_input, "FLEN.csv"))
nucdf = pd.read_csv(os.path.join(path_to_main_input, "NUCLEOSOME.csv"))

metadata = pd.read_excel("Metadata_TN_TP_MRDGW.xlsx")

# %%
metadata
# Out:
#      Samle ID  Cancer True label    Run     Kit           Batch data
# 0     ZMB001D  Breast          -  R5453  No UID         batch_170724
# 1     ZMB002C  Breast          -  R5422  No UID         batch_120724
# 2     ZMB003D  Breast          -  R5422  No UID         batch_120724
# 3     ZMB007D  Breast          -  R5444  No UID  batch_150724_160724
# 4     ZMB009B  Breast          -  R5435  No UID  batch_150724_160724
# ..        ...     ...        ...    ...     ...                  ...
# 239    QHAA44    Lung          -  R5589  No UID         batch_130824
# 240    UHAA21    Lung          -  R5589  No UID         batch_130824
# 241  MUGAAA20    Lung          -  R5589  No UID         batch_130824
# 242  MUGAAA72    Lung          -  R5589  No UID         batch_130824
# 243  MUGAAB67    Lung          -  R5589  No UID         batch_130824
#
# [244 rows x 6 columns]
